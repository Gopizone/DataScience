# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopizone/DS/blob/main/Neural_Network_Hyperparameter_Tuning(pima_indians_diabetes).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fa2fef96-4efd-4f70-99a1-cf4b17900938" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa2fef96-4efd-4f70-99a1-cf4b17900938">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pima-indians-diabetes.csv to pima-indians-diabetes.csv

# %%
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1  ...             6             7
# count  7.680000e+02  7.680000e+02  ...  7.680000e+02  7.680000e+02
# mean  -7.748432e-17  3.614007e-18  ...  1.924387e-15  2.192980e-16
# std    1.000652e+00  1.000652e+00  ...  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00  ... -1.189553e+00 -1.041549e+00
# 25%   -8.448851e-01 -6.852363e-01  ... -6.889685e-01 -7.862862e-01
# 50%   -2.509521e-01 -1.218877e-01  ... -3.001282e-01 -3.608474e-01
# 75%    6.399473e-01  6.057709e-01  ...  4.662269e-01  6.602056e-01
# max    3.906578e+00  2.444478e+00  ...  5.883565e+00  4.063716e+00
#
# [8 rows x 8 columns]

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
import tensorflow as tf
from sklearn.model_selection import GridSearchCV, KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['acc'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............ batch_size=10, epochs=10, score=0.734, total=   2.1s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.688, total=   1.1s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.2s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.753, total=   1.1s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.4s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.830, total=   1.1s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    5.5s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.758, total=   1.1s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    6.6s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.721, total=   3.2s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    9.8s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.682, total=   3.1s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   12.9s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.727, total=   3.0s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   15.9s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.797, total=   2.9s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   18.8s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.778, total=   3.0s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.734, total=   5.4s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.701, total=   5.2s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.727, total=   5.4s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.784, total=   5.2s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.791, total=   5.3s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.760, total=   1.1s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.714, total=   0.8s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.753, total=   0.8s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.817, total=   0.8s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.778, total=   0.8s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.734, total=   1.8s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.721, total=   1.8s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.727, total=   1.8s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.752, total=   1.8s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.758, total=   2.0s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.747, total=   2.9s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.682, total=   3.0s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.740, total=   3.1s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.732, total=   3.0s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.712, total=   3.1s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.753, total=   0.7s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.701, total=   0.7s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.753, total=   0.8s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.843, total=   1.0s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.771, total=   0.7s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.708, total=   1.2s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.701, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.734, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.765, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.752, total=   1.3s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.708, total=   2.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.636, total=   2.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.740, total=   2.1s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.784, total=   1.9s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.765, total=   1.9s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  1.6min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7644342541694641, using {'batch_size': 40, 'epochs': 10}
# 0.7527119994163514,0.04586929087119399 with: {'batch_size': 10, 'epochs': 10}
# 0.7410067200660706,0.041549365356672786 with: {'batch_size': 10, 'epochs': 50}
# 0.747500228881836,0.034544935364203826 with: {'batch_size': 10, 'epochs': 100}
# 0.7644087910652161,0.03347413155561525 with: {'batch_size': 20, 'epochs': 10}
# 0.7383244395256042,0.014295031318605968 with: {'batch_size': 20, 'epochs': 50}
# 0.7226551413536072,0.023455951303300415 with: {'batch_size': 20, 'epochs': 100}
# 0.7644342541694641,0.04577537586758962 with: {'batch_size': 40, 'epochs': 10}
# 0.7318394184112549,0.024440727849504715 with: {'batch_size': 40, 'epochs': 50}
# 0.7266870498657226,0.05189570702830411 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.760, total=   0.9s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.584, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.7s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.753, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.5s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.837, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.3s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.765, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.1s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.753, total=   1.0s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.1s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.734, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    5.9s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.773, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    6.6s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.830, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    7.4s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.784, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.760, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.688, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.727, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.810, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.758, total=   1.1s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.649, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.721, total=   0.7s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.779, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.810, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.745, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.734, total=   0.7s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.721, total=   0.7s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.747, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.837, total=   1.1s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.758, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.701, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.734, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.734, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.824, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.732, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.649, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.708, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.753, total=   1.1s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.804, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.732, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.747, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.734, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.773, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.843, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.752, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.753, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.708, total=   1.1s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.760, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.830, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.745, total=   0.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   36.8s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7748238682746887, using {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7397419452667237,0.083322907823899 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7748238682746887,0.032549584995638974 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7487904310226441,0.040327143120912824 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7409812450408936,0.05497354029143022 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7592140078544617,0.04066933703084935 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7448773622512818,0.041224536017990344 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7292674660682679,0.05099752283241215 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7696036100387573,0.03884923646430732 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.7591885209083558,0.039747346446215345 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=softmax, init=uniform, score=0.649, total=   0.8s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.584, total=   0.8s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.7s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.630, total=   0.8s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.5s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.745, total=   0.8s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.4s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.647, total=   0.9s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.3s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.649, total=   1.3s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.6s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.584, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    6.4s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.630, total=   0.9s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    7.3s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.745, total=   0.9s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    8.1s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.647, total=   0.9s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.416, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.745, total=   0.9s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.647, total=   1.2s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.649, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.669, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.747, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.824, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.765, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.649, total=   0.9s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.727, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.766, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.804, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.647, total=   1.2s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.584, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.745, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.647, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.753, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.701, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.740, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.830, total=   0.9s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.778, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.747, total=   1.2s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.695, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.747, total=   0.9s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.797, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.758, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.584, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.745, total=   0.9s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.647, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.753, total=   1.3s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.675, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.753, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.843, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.771, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.740, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.701, total=   0.9s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.740, total=   0.9s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.824, total=   0.9s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.752, total=   0.8s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.584, total=   1.3s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.745, total=   0.9s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.647, total=   0.9s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:   52.6s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7605296730995178, using {'activation_function': 'tanh', 'init': 'uniform'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.6173924148082733,0.10871275688841411 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.730634081363678,0.06399509135465509 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.718767511844635,0.06250989055169583 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7605296730995178,0.042673007072287765 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.7487734675407409,0.03277856684841025 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7592394471168518,0.053472264016427185 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7513963341712951,0.0399025230791139 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................ neuron1=4, neuron2=2, score=0.760, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.669, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.740, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.4s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.817, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.2s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.739, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.1s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.753, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    4.8s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.688, total=   1.2s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    6.1s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.740, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    6.9s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.804, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    7.7s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.758, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.753, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.682, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.727, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.824, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.765, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.753, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.682, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.740, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.797, total=   1.2s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.758, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.760, total=   0.9s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.688, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.753, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.810, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.765, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.766, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.701, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.753, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.837, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.758, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.766, total=   1.3s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.714, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.760, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.804, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.758, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.766, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.708, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.753, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.830, total=   1.0s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.778, total=   0.9s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.766, total=   0.9s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.747, total=   1.3s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.753, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.837, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.765, total=   0.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   38.8s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7735081911087036, using {'neuron1': 16, 'neuron2': 8}
# 0.7448773503303527,0.04746760306826742 with: {'neuron1': 4, 'neuron2': 2}
# 0.748781943321228,0.03708834531898134 with: {'neuron1': 4, 'neuron2': 4}
# 0.7501145958900451,0.046472792946489844 with: {'neuron1': 4, 'neuron2': 8}
# 0.7461760520935059,0.037398412675074114 with: {'neuron1': 8, 'neuron2': 2}
# 0.7552924156188965,0.03909523738914467 with: {'neuron1': 8, 'neuron2': 4}
# 0.763110089302063,0.043250560343975904 with: {'neuron1': 8, 'neuron2': 8}
# 0.7604702472686767,0.028495859431261632 with: {'neuron1': 16, 'neuron2': 2}
# 0.7670231699943543,0.03946821402137044 with: {'neuron1': 16, 'neuron2': 4}
# 0.7735081911087036,0.0323650832361465 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 16,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/wrappers/scikit_learn.py:241: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# 0.7786458333333334

# %% [markdown]
# # Hyperparameters all at once

# %% [markdown]
# The hyperparameter optimization was carried out by taking 2 hyperparameters at once. We may have missed the best values. The performance can be further improved by finding the optimum values of hyperparameters all at once given by the code snippet below.
# #### This process is computationally expensive.

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.649, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.584, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.4s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.630, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.6s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.745, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.7s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.353, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    5.9s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.649, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    7.1s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.584, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    8.2s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.630, total=   1.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    9.8s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.745, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   11.0s remaining:    0.0s
# Streaming output truncated to the last 5000 lines.
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.753, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.830, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.758, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.727, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.695, total=   5.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.773, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.797, total=   6.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.784, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.740, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.688, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.766, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.804, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.778, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.740, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.708, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.753, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.824, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.758, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.714, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.643, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.766, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.784, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.797, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.740, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.701, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.747, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.778, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.797, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.688, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.675, total=   7.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.766, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.778, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.817, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.714, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.649, total=   6.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.773, total=   7.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.706, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.784, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.734, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.695, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.773, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.771, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.745, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.753, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.682, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.766, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.745, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.784, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.721, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.669, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.786, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.824, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.745, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.701, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.695, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.766, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.843, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.745, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.734, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.734, total=   6.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.747, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.830, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.765, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.675, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.695, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.753, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.693, total=   7.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.752, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.727, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.675, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.773, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.824, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.745, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.695, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.708, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.766, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.778, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.725, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.708, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.682, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.805, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.752, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.725, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.714, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.688, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.792, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.797, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.745, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.721, total=   6.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.701, total=   6.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.727, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.686, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.739, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.747, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.688, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.753, total=   5.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.810, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.778, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.753, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.708, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.753, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.843, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.771, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.753, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.721, total=   7.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.753, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.850, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.752, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.727, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.727, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.766, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.824, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.771, total=   6.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4, score=0.721, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4, score=0.714, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4, score=0.773, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4, score=0.817, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=4, score=0.752, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8, score=0.721, total=   6.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8, score=0.721, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8, score=0.766, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8, score=0.830, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=8, neuron2=8, score=0.765, total=   6.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2, score=0.727, total=   6.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2, score=0.701, total=   6.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2, score=0.753, total=   6.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2, score=0.830, total=   6.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=2, score=0.758, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4, score=0.734, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4, score=0.688, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4, score=0.766, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4, score=0.804, total=   6.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=4, score=0.758, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8, score=0.727, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8, score=0.695, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8, score=0.747, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8, score=0.837, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.001, neuron1=16, neuron2=8, score=0.765, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2, score=0.734, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2, score=0.675, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2, score=0.747, total=   5.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2, score=0.817, total=   5.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2, score=0.810, total=   7.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4, score=0.740, total=   8.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4, score=0.675, total=   5.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4, score=0.773, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4, score=0.850, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4, score=0.765, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=8, score=0.740, total=   5.5s
# ...
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.765, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.727, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.695, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.779, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.771, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.778, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.708, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.675, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.740, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.797, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.752, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.708, total=   5.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.662, total=   7.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.747, total=   6.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.791, total=   6.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.791, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.734, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.701, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.740, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.784, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.771, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.721, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.675, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.753, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.758, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.804, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.747, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.675, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.727, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.810, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.771, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.649, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.669, total=   5.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.740, total=   5.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.745, total=   5.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.752, total=   5.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.688, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.662, total=   9.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.753, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.765, total=   6.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.732, total=   5.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.740, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.714, total=   5.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.727, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.817, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.693, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.682, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.760, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.630, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.791, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.725, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.727, total=   5.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.695, total=   5.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
