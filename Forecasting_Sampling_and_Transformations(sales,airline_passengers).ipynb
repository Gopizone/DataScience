# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopizone/DataScience/blob/main/Forecasting_Sampling_and_Transformations(sales%2Cairline_passengers).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files=files.upload()
# Out:
#      <input type="file" id="files-0ca9512d-72a4-4ddd-a4c2-5ec593ebb7d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ca9512d-72a4-4ddd-a4c2-5ec593ebb7d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sales.csv to sales.csv

# %% [markdown]
# #### Upsampling Data

# %%
# upsample to daily intervals
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot

# %%
series = read_csv('sales.csv', header=0, index_col=0, parse_dates=True,squeeze=True)

# %%
upsampled = series.resample('D').mean()
print(upsampled.head(32))
# Out:
# Month
# 1990-01-01    266.0
# 1990-01-02      NaN
# 1990-01-03      NaN
# 1990-01-04      NaN
# 1990-01-05      NaN
# 1990-01-06      NaN
# 1990-01-07      NaN
# 1990-01-08      NaN
# 1990-01-09      NaN
# 1990-01-10      NaN
# 1990-01-11      NaN
# 1990-01-12      NaN
# 1990-01-13      NaN
# 1990-01-14      NaN
# 1990-01-15      NaN
# 1990-01-16      NaN
# 1990-01-17      NaN
# 1990-01-18      NaN
# 1990-01-19      NaN
# 1990-01-20      NaN
# 1990-01-21      NaN
# 1990-01-22      NaN
# 1990-01-23      NaN
# 1990-01-24      NaN
# 1990-01-25      NaN
# 1990-01-26      NaN
# 1990-01-27      NaN
# 1990-01-28      NaN
# 1990-01-29      NaN
# 1990-01-30      NaN
# 1990-01-31      NaN
# 1990-02-01    145.9
# Freq: D, Name: Sales, dtype: float64

# %% [markdown]
# ##### interpolate the missing value

# %%
interpolated = upsampled.interpolate(method='linear')
print(interpolated.head(32))
interpolated.plot()
pyplot.show()
# Out:
# Month
# 1990-01-01    266.000000
# 1990-01-02    262.125806
# 1990-01-03    258.251613
# 1990-01-04    254.377419
# 1990-01-05    250.503226
# 1990-01-06    246.629032
# 1990-01-07    242.754839
# 1990-01-08    238.880645
# 1990-01-09    235.006452
# 1990-01-10    231.132258
# 1990-01-11    227.258065
# 1990-01-12    223.383871
# 1990-01-13    219.509677
# 1990-01-14    215.635484
# 1990-01-15    211.761290
# 1990-01-16    207.887097
# 1990-01-17    204.012903
# 1990-01-18    200.138710
# 1990-01-19    196.264516
# 1990-01-20    192.390323
# 1990-01-21    188.516129
# 1990-01-22    184.641935
# 1990-01-23    180.767742
# 1990-01-24    176.893548
# 1990-01-25    173.019355
# 1990-01-26    169.145161
# 1990-01-27    165.270968
# 1990-01-28    161.396774
# 1990-01-29    157.522581
# 1990-01-30    153.648387
# 1990-01-31    149.774194
# 1990-02-01    145.900000
# Freq: D, Name: Sales, dtype: float64

# %% [markdown]
# #### Downsampling Data

# %%
# downsample to quarterly intervals
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot

# %%
resample = series.resample('Q')
quarterly_mean_sales = resample.mean()

# %% [markdown]
# # Tranformations

# %%
from google.colab import files
files=files.upload()
# Out:
#      <input type="file" id="files-30f03f6c-1ad1-4b75-9a58-b25a5df3a26e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30f03f6c-1ad1-4b75-9a58-b25a5df3a26e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving airline-passengers.csv to airline-passengers.csv

# %%
# load and plot a time series
from pandas import read_csv
from matplotlib import pyplot

# %%
series = read_csv('airline-passengers.csv', header=0, index_col=0, parse_dates=True)

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(series)
# histogram
pyplot.subplot(212)
pyplot.hist(series)
pyplot.show()

# %% [markdown]
# #### Square Root Transform

# %%
from pandas import read_csv
from pandas import DataFrame
from numpy import sqrt
from matplotlib import pyplot

# %%
dataframe = DataFrame(series.values)
dataframe.columns = ['passengers']
dataframe['passengers'] = sqrt(dataframe['passengers'])

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(dataframe['passengers'])
# histogram
pyplot.subplot(212)
pyplot.hist(dataframe['passengers'])
pyplot.show()

# %% [markdown]
# #### Log Transform

# %%
from numpy import log
dataframe = DataFrame(series.values)
dataframe.columns = ['passengers']
dataframe['passengers'] = log(dataframe['passengers'])

# line plot
pyplot.subplot(211)
pyplot.plot(dataframe['passengers'])
# histogram
pyplot.subplot(212)
pyplot.hist(dataframe['passengers'])
pyplot.show()

# %%
print(quarterly_mean_sales.head())
quarterly_mean_sales.plot()
pyplot.show()
# Out:
# Month
# 1990-03-31    198.333333
# 1990-06-30    156.033333
# 1990-09-30    216.366667
# 1990-12-31    215.100000
# 1991-03-31    184.633333
# Freq: Q-DEC, Name: Sales, dtype: float64
